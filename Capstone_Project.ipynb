# %% [markdown]
# <a href="https://colab.research.google.com/github/Enell261/Python-Projects/blob/main/Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import the necessary modules

import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import json
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
from geopy.geocoders import Nominatim

# %% [markdown]
# We want to get a list of all the suburbs in Pretoria
#
# ---

# %%
#Get the html from the wikipedia page containing the list
url = 'https://en.wikipedia.org/wiki/List_of_Pretoria_suburbs'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Get a list of all the elements corresponding to the Pretoria suburbs
pta_east = soup.find_all('ul')[1]
pta_ne = soup.find_all('ul')[2]
pta_nw = soup.find_all('ul')[3]
pta_cw = soup.find_all('ul')[4]

# %%
#Create a list of all the links for the suburbs on the page
links = []
burbs = [pta_east, pta_ne, pta_nw, pta_cw]
for suburb in burbs:
  suburbs_links = suburb.find_all('a')
  links.append(suburbs_links)

# %%
#links is a nested link, we unnest it using itertools
from itertools import chain
links = list(chain(*links))

# %%
len(links)
# Out:
# 102

# %%
#Extract the suburb names from the list
suburbs = []
for link in links:
    title = link.contents
    suburbs.append(title)

# %%
#Suburbs is a nested list, we need to unnest it using itertools
suburbs = list(chain(*suburbs))

# %%
# Add the string ', Pretoria' for easier geocoding later
suburbs = [s + ', Pretoria' for s in suburbs]

# %%
suburbs = pd.DataFrame({'Suburb':suburbs})

# %%
suburbs.head()
# Out:
#                      Suburb
# 0     Alphen Park, Pretoria
# 1         Arcadia, Pretoria
# 2  Ashlea Gardens, Pretoria
# 3        Brooklyn, Pretoria
# 4       Brummeria, Pretoria

# %% [markdown]
# We need to manually geocode each suburb as there is such no dataset readily available

# %%
pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 3.9MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from geocoder) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from geocoder) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from geocoder) (2.23.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from geocoder) (0.16.0)
# Collecting ratelim
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->geocoder) (2.10)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ratelim->geocoder) (4.4.2)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Downloading https://files.pythonhosted.org/packages/2a/9f/e8a440a993e024c0d3d4e5c7d3346367c50c9a1a3d735caf5ee3bde0aab1/geopandas-0.8.2-py2.py3-none-any.whl (962kB)
#      |████████████████████████████████| 972kB 5.9MB/s
# Requirement already satisfied: shapely in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.7.1)
# Collecting fiona
#   Downloading https://files.pythonhosted.org/packages/37/94/4910fd55246c1d963727b03885ead6ef1cd3748a465f7b0239ab25dfc9a3/Fiona-1.8.18-cp36-cp36m-manylinux1_x86_64.whl (14.8MB)
#      |████████████████████████████████| 14.8MB 306kB/s
# Collecting pyproj>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/e4/ab/280e80a67cfc109d15428c0ec56391fc03a65857b7727cf4e6e6f99a4204/pyproj-3.0.0.post1-cp36-cp36m-manylinux2010_x86_64.whl (6.4MB)
#      |████████████████████████████████| 6.5MB 38.6MB/s
# Requirement already satisfied: pandas>=0.23.0 in /usr/local/lib/python3.6/dist-packages (from geopandas) (1.1.5)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (1.15.0)
# Requirement already satisfied: click<8,>=4.0 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (7.1.2)
# Collecting click-plugins>=1.0
#   Downloading https://files.pythonhosted.org/packages/e9/da/824b92d9942f4e472702488857914bdd50f73021efea15b4cad9aca8ecef/click_plugins-1.1.1-py2.py3-none-any.whl
# Collecting munch
#   Downloading https://files.pythonhosted.org/packages/cc/ab/85d8da5c9a45e072301beb37ad7f833cd344e04c817d97e0cc75681d248f/munch-2.5.0-py2.py3-none-any.whl
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (2020.12.5)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.6/dist-packages (from fiona->geopandas) (20.3.0)
# Collecting cligj>=0.5
#   Downloading https://files.pythonhosted.org/packages/42/1e/947eadf10d6804bf276eb8a038bd5307996dceaaa41cfd21b7a15ec62f5d/cligj-0.7.1-py3-none-any.whl
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2018.9)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.23.0->geopandas) (2.8.1)
# Installing collected packages: click-plugins, munch, cligj, fiona, pyproj, geopandas
# Successfully installed click-plugins-1.1.1 cligj-0.7.1 fiona-1.8.18 geopandas-0.8.2 munch-2.5.0 pyproj-3.0.0.post1

# %%
pip install geopy
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.6/dist-packages (1.17.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /usr/local/lib/python3.6/dist-packages (from geopy) (1.50)

# %% [markdown]
# Get coordinates for each suburb

# %%
from geopy.extra.rate_limiter import RateLimiter
#create a Nominatim instance
locator = Nominatim(user_agent="myGeocoder")
#create function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
#create location column
suburbs['location'] = suburbs['Suburb'].apply(geocode)
#create longitude, laatitude and altitude from location column (returns tuple)
suburbs['point'] = suburbs['location'].apply(lambda loc: tuple(loc.point) if loc else None)
# split point column into latitude, longitude and altitude columns
suburbs[['latitude', 'longitude', 'altitude']] = pd.DataFrame(suburbs['point'].tolist(), index=suburbs.index)

# %%
# we only need the suburb and its coordinates
suburbs.drop(['location', 'point', 'altitude'], axis=1, inplace=True)

# %%
#drop suburbs with missing coordinates
suburbs.dropna(inplace=True)

# %%
suburbs.to_csv('Pretoria Geospatial data.csv', index=False)

# %%
suburbs.head()
# Out:
#                      Suburb   latitude  longitude
# 0     Alphen Park, Pretoria -25.782890  28.263953
# 1         Arcadia, Pretoria -25.745627  28.210221
# 2  Ashlea Gardens, Pretoria -25.785833  28.264167
# 3        Brooklyn, Pretoria -25.765556  28.239722
# 4       Brummeria, Pretoria -25.744224  28.283561

# %% [markdown]
# **Mapping Pretoria and its suburbs**<br>
# We now use folium to create a map of Pretoria with markers

# %%
# Declare the address as Pretoria

address = 'Pretoria, South Africa'

# Get the coordinates for Toronto using geolocator
locat = locator.geocode(address)
latitude = locat.latitude
longitude = locat.longitude

# %%
print('The geograpical coordinate of Pretoria are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Pretoria are -25.7459374, 28.1879444.

# %%
# draw a map of Pretoria

pta_map = folium.Map(location=[latitude, longitude], zoom_start=11)

#add markers to the map

for lat, lng, label in zip(suburbs['latitude'], suburbs['longitude'], suburbs['Suburb']):
  label = folium.Popup(label, parse_html=True)
  folium.CircleMarker(
      [lat, lng],
      radius=5,
      popup=label,
      color='blue',
      fill=True,
      fill_color='#3186cc',
      fill_opacity=0.7,
      parse_html=False).add_to(pta_map)

# %%
pta_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_0dd544ea015848aba46f0f9141bafb6c%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_0dd544ea015848aba46f0f9141bafb6c%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_0dd544ea015848aba46f0f9141bafb6c%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_0dd544ea015848aba46f0f9141bafb6c%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-25.7459374%2C%2028.1879444%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_15dcf9c4025f4571b5bfa1657e5e04d6%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %% [markdown]
# We access Foursquare for Pretoria data

# %%
CLIENT_ID = 'PJX3PJ4FIED23NYXJEMYAHHJH0S4UHKZRL214FEKVLMT13FW' # my Foursquare ID
CLIENT_SECRET = 'HHUGJ5DXTGCJ35ORN5DJXXCM5ZPS42ESFGJ4TX2ICJULGLAX' # my Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 100 # A default Foursquare API limit value

# %%
# get url for Pretoria from Foursquare

LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 3000 # define radius as 3km

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)

url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=PJX3PJ4FIED23NYXJEMYAHHJH0S4UHKZRL214FEKVLMT13FW&client_secret=HHUGJ5DXTGCJ35ORN5DJXXCM5ZPS42ESFGJ4TX2ICJULGLAX&v=20180605&ll=-25.7459374,28.1879444&radius=3000&limit=100'

# %%
# Create the json file for the Pretoria data from Foursquare
results = requests.get(url).json()

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                          name  ...        lng
# 0                                  Café Riche  ...  28.187304
# 1                                Pretoria Zoo  ...  28.188903
# 2                               State Theatre  ...  28.195084
# 3  National Zoological Gardens (Pretoria Zoo)  ...  28.191047
# 4                    Manhattan Hotel Pretoria  ...  28.191166
#
# [5 rows x 4 columns]

# %%
#Get the number of venues returned by the function
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 53 venues were returned by Foursquare.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=1000):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
#Create a dataframe
pta_venues = getNearbyVenues(names=suburbs['Suburb'],
                                   latitudes=suburbs['latitude'],
                                   longitudes=suburbs['longitude']
                                  )
# Out:
# Alphen Park, Pretoria
# Arcadia, Pretoria
# Ashlea Gardens, Pretoria
# Brooklyn, Pretoria
# Brummeria, Pretoria
# Bryntirion, Pretoria
# Colbyn, Pretoria
# Constantiapark, Pretoria
# Die Wilgers, Pretoria
# Eastwood, Pretoria
# Elarduspark, Pretoria
# Erasmuskloof, Pretoria
# Erasmusrand, Pretoria
# Faerie Glen, Pretoria
# Garsfontein, Pretoria
# Groenkloof, Pretoria
# Hatfield, Pretoria
# Hazeldene, Pretoria
# Hazelwood, Pretoria
# Hillcrest, Pretoria
# La Montagne, Pretoria
# Lukasrand, Pretoria
# Lydiana, Pretoria
# Lynnwood, Pretoria
# Lynnwood Glen, Pretoria
# Lynnwood Manor, Pretoria
# Lynnwood Park, Pretoria
# Lynnwood Ridge, Pretoria
# Menlo Park, Pretoria
# Menlyn, Pretoria
# Meyerspark, Pretoria
# Monument Park, Pretoria
# Moreleta Park, Pretoria
# Muckleneuk, Pretoria
# Murrayfield, Pretoria
# New Muckleneuk, Pretoria
# Newlands, Pretoria
# Olympus, Pretoria
# Rietvalleirand, Pretoria
# Sterrewag, Pretoria
# Sunnyside, Pretoria
# Trevenna, Pretoria
# Val de Grace, Pretoria
# Wapadrand, Pretoria
# Waterkloof, Pretoria
# Waterkloof Glen, Pretoria
# Waterkloof Park, Pretoria
# Waterkloof Ridge, Pretoria
# Willow Glen, Pretoria
# Wingate Park, Pretoria
# Woodhill, Pretoria
# Woodlands, Pretoria
# Mamelodi, Pretoria
# Montana Park, Pretoria
# Silverton, Pretoria
# Sinoville, Pretoria
# Waverley, Pretoria
# Wonderboom South, Pretoria
# Amandasig, Pretoria
# Booysens, Pretoria
# Claremont, Pretoria
# Chantelle, Pretoria
# Karenpark, Pretoria
# Phillip Nel Park, Pretoria
# Pretoria North, Pretoria
# Rosslyn, Pretoria
# The Orchards, Pretoria
# Orchards, Pretoria
# Theresapark, Pretoria
# Wolmer, Pretoria
# Atteridgeville, Pretoria
# Lotus Gardens, Pretoria
# Capital Park, Pretoria
# Danville, Pretoria
# Daspoort, Pretoria
# Elandspoort, Pretoria
# Eloffsdal, Pretoria
# Hermanstad, Pretoria
# Kwaggasrand, Pretoria
# Laudium, Pretoria
# Les Marais, Pretoria
# Mayville, Pretoria
# Mountain View, Pretoria
# Pretoria West, Pretoria
# Proclamation Hill, Pretoria
# Salvokop, Pretoria
# Weskoppies, Pretoria
# Wespark, Pretoria

# %%
# Check the number of venues per neighbourh
pta_venues.groupby('Neighbourhood').count()
# Out:
#                             Neighbourhood Latitude  ...  Venue Category
# Neighbourhood                                       ...
# Alphen Park, Pretoria                           12  ...              12
# Amandasig, Pretoria                              2  ...               2
# Arcadia, Pretoria                               22  ...              22
# Ashlea Gardens, Pretoria                         5  ...               5
# Atteridgeville, Pretoria                         3  ...               3
# ...                                            ...  ...             ...
# Wingate Park, Pretoria                          12  ...              12
# Wolmer, Pretoria                                 6  ...               6
# Wonderboom South, Pretoria                       5  ...               5
# Woodhill, Pretoria                              37  ...              37
# Woodlands, Pretoria                             25  ...              25
#
# [88 rows x 6 columns]

# %%
# one hot encoding
pta_coded = pd.get_dummies(pta_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
pta_coded['Neighbourhood'] = pta_venues['Neighbourhood'] 

# move neighborhood column to the first column
fixed_columns = [pta_coded.columns[-1]] + list(pta_coded.columns[:-1])
pta_coded = pta_coded[fixed_columns]

pta_coded.head()
# Out:
#            Neighbourhood  ATM  African Restaurant  ...  Video Store  Wine Shop  Zoo
# 0  Alphen Park, Pretoria    0                   0  ...            0          0    0
# 1  Alphen Park, Pretoria    0                   0  ...            0          0    0
# 2  Alphen Park, Pretoria    0                   0  ...            0          0    0
# 3  Alphen Park, Pretoria    0                   0  ...            0          0    0
# 4  Alphen Park, Pretoria    0                   0  ...            0          0    0
#
# [5 rows x 140 columns]

# %%
pta_grouped = pta_coded.groupby('Neighbourhood').mean().reset_index()
pta_grouped
# Out:
#                  Neighbourhood  ATM  ...  Wine Shop  Zoo
# 0        Alphen Park, Pretoria  0.0  ...        0.0  0.0
# 1          Amandasig, Pretoria  0.0  ...        0.0  0.0
# 2            Arcadia, Pretoria  0.0  ...        0.0  0.0
# 3     Ashlea Gardens, Pretoria  0.0  ...        0.0  0.0
# 4     Atteridgeville, Pretoria  0.0  ...        0.0  0.0
# ..                         ...  ...  ...        ...  ...
# 83      Wingate Park, Pretoria  0.0  ...        0.0  0.0
# 84            Wolmer, Pretoria  0.0  ...        0.0  0.0
# 85  Wonderboom South, Pretoria  0.0  ...        0.0  0.0
# 86          Woodhill, Pretoria  0.0  ...        0.0  0.0
# 87         Woodlands, Pretoria  0.0  ...        0.0  0.0
#
# [88 rows x 140 columns]

# %%
num_top_venues = 5

for hood in pta_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = pta_grouped[pta_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Alphen Park, Pretoria----
#                 venue  freq
# 0          Restaurant  0.17
# 1               Hotel  0.17
# 2                Café  0.08
# 3        Intersection  0.08
# 4  Italian Restaurant  0.08
#
#
# ----Amandasig, Pretoria----
#                         venue  freq
# 0               Garden Center   0.5
# 1        Fast Food Restaurant   0.5
# 2                         ATM   0.0
# 3          Miscellaneous Shop   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Arcadia, Pretoria----
#                   venue  freq
# 0                 Hotel  0.18
# 1  Fast Food Restaurant  0.09
# 2         Shopping Mall  0.09
# 3                  Café  0.09
# 4        Breakfast Spot  0.09
#
#
# ----Ashlea Gardens, Pretoria----
#                         venue  freq
# 0                       Hotel   0.4
# 1                  Restaurant   0.4
# 2          Italian Restaurant   0.2
# 3  Modern European Restaurant   0.0
# 4               Movie Theater   0.0
#
#
# ----Atteridgeville, Pretoria----
#                         venue  freq
# 0               Shopping Mall  0.67
# 1              Clothing Store  0.33
# 2                         ATM  0.00
# 3                    Platform  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Booysens, Pretoria----
#                         venue  freq
# 0                      Resort  0.17
# 1        Fast Food Restaurant  0.17
# 2                 Gas Station  0.17
# 3  Construction & Landscaping  0.17
# 4                 Karaoke Bar  0.17
#
#
# ----Brooklyn, Pretoria----
#           venue  freq
# 0          Café  0.10
# 1   Coffee Shop  0.07
# 2    Restaurant  0.07
# 3      Pharmacy  0.05
# 4  Burger Joint  0.05
#
#
# ----Brummeria, Pretoria----
#            venue  freq
# 0           Café  0.50
# 1  Shopping Mall  0.25
# 2           Road  0.25
# 3            ATM  0.00
# 4    Pizza Place  0.00
#
#
# ----Bryntirion, Pretoria----
#                 venue  freq
# 0          Restaurant  0.29
# 1       Shopping Mall  0.14
# 2                Park  0.14
# 3   Convenience Store  0.14
# 4  Italian Restaurant  0.14
#
#
# ----Capital Park, Pretoria----
#               venue  freq
# 0               Spa   0.2
# 1     Train Station   0.2
# 2              Café   0.2
# 3  Stationery Store   0.2
# 4     Garden Center   0.2
#
#
# ----Chantelle, Pretoria----
#                        venue  freq
# 0              Garden Center   0.5
# 1               Neighborhood   0.5
# 2                        ATM   0.0
# 3  Middle Eastern Restaurant   0.0
# 4          Mobile Phone Shop   0.0
#
#
# ----Claremont, Pretoria----
#            venue  freq
# 0   Home Service   0.2
# 1    Gas Station   0.2
# 2    Video Store   0.2
# 3  Auto Workshop   0.2
# 4         Resort   0.2
#
#
# ----Colbyn, Pretoria----
#                   venue  freq
# 0  Fast Food Restaurant  0.16
# 1    Seafood Restaurant  0.12
# 2          Burger Joint  0.08
# 3           Golf Course  0.08
# 4           Supermarket  0.04
#
#
# ----Constantiapark, Pretoria----
#                   venue  freq
# 0      Asian Restaurant   0.4
# 1      Department Store   0.2
# 2    Mexican Restaurant   0.2
# 3        Shop & Service   0.2
# 4  Other Great Outdoors   0.0
#
#
# ----Danville, Pretoria----
#                    venue  freq
# 0   Fast Food Restaurant  0.25
# 1              Wine Shop  0.25
# 2  Portuguese Restaurant  0.25
# 3           Liquor Store  0.25
# 4                    ATM  0.00
#
#
# ----Daspoort, Pretoria----
#                         venue  freq
# 0               Grocery Store   1.0
# 1                         ATM   0.0
# 2                   Nightclub   0.0
# 3           Mobile Phone Shop   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Die Wilgers, Pretoria----
#                   venue  freq
# 0           Pizza Place  0.25
# 1         Grocery Store  0.17
# 2  Fast Food Restaurant  0.17
# 3         Shopping Mall  0.17
# 4    Italian Restaurant  0.08
#
#
# ----Eastwood, Pretoria----
#                   venue  freq
# 0            Steakhouse  0.33
# 1              Pharmacy  0.17
# 2  Fast Food Restaurant  0.17
# 3    Seafood Restaurant  0.17
# 4         Grocery Store  0.17
#
#
# ----Elandspoort, Pretoria----
#       venue  freq
# 0  Pharmacy  0.25
# 1      Park  0.25
# 2    Market  0.25
# 3    Lounge  0.25
# 4       ATM  0.00
#
#
# ----Elarduspark, Pretoria----
#                 venue  freq
# 0       Shopping Mall  0.25
# 1                 Gym  0.12
# 2  Seafood Restaurant  0.12
# 3  Chinese Restaurant  0.12
# 4         Supermarket  0.12
#
#
# ----Eloffsdal, Pretoria----
#                   venue  freq
# 0  Fast Food Restaurant   0.2
# 1         Train Station   0.2
# 2          Liquor Store   0.2
# 3            Steakhouse   0.2
# 4         Grocery Store   0.2
#
#
# ----Erasmuskloof, Pretoria----
#                 venue  freq
# 0                Café  0.17
# 1       Shopping Mall  0.17
# 2    Asian Restaurant  0.17
# 3  Italian Restaurant  0.17
# 4   Convenience Store  0.17
#
#
# ----Erasmusrand, Pretoria----
#                   venue  freq
# 0         Grocery Store  0.25
# 1                  Café  0.25
# 2          Concert Hall  0.25
# 3                   Gym  0.25
# 4  Other Great Outdoors  0.00
#
#
# ----Faerie Glen, Pretoria----
#                 venue  freq
# 0       Shopping Mall  0.18
# 1          Restaurant  0.12
# 2         Pizza Place  0.06
# 3  Chinese Restaurant  0.06
# 4  Seafood Restaurant  0.06
#
#
# ----Garsfontein, Pretoria----
#                 venue  freq
# 0  Italian Restaurant  0.14
# 1          Restaurant  0.14
# 2              Bistro  0.09
# 3                Café  0.09
# 4    Sushi Restaurant  0.05
#
#
# ----Groenkloof, Pretoria----
#                   venue  freq
# 0     Food & Drink Shop  0.14
# 1     Indian Restaurant  0.07
# 2             BBQ Joint  0.07
# 3           Coffee Shop  0.07
# 4  Other Great Outdoors  0.07
#
#
# ----Hatfield, Pretoria----
#                   venue  freq
# 0  Fast Food Restaurant  0.10
# 1          Cocktail Bar  0.04
# 2                   Bar  0.04
# 3         Grocery Store  0.04
# 4    Seafood Restaurant  0.04
#
#
# ----Hazeldene, Pretoria----
#                   venue  freq
# 0          Burger Joint  0.16
# 1                 Hotel  0.12
# 2  Fast Food Restaurant  0.12
# 3         Shopping Mall  0.08
# 4        History Museum  0.08
#
#
# ----Hazelwood, Pretoria----
#                 venue  freq
# 0  Italian Restaurant  0.07
# 1          Restaurant  0.07
# 2       Shopping Mall  0.07
# 3         Coffee Shop  0.07
# 4         Pizza Place  0.07
#
#
# ----Hermanstad, Pretoria----
#                            venue  freq
# 0                       Platform  0.25
# 1                  Train Station  0.25
# 2                    Gas Station  0.25
# 3                  Grocery Store  0.25
# 4  Paper / Office Supplies Store  0.00
#
#
# ----Hillcrest, Pretoria----
#         venue  freq
# 0        Café  0.10
# 1         Pub  0.10
# 2         Bar  0.10
# 3  Restaurant  0.10
# 4    Pharmacy  0.05
#
#
# ----Karenpark, Pretoria----
#                    venue  freq
# 0          Shopping Mall  0.12
# 1          Grocery Store  0.12
# 2     Seafood Restaurant  0.06
# 3     Italian Restaurant  0.06
# 4  Portuguese Restaurant  0.06
#
#
# ----Kwaggasrand, Pretoria----
#                         venue  freq
# 0                 Pizza Place   0.5
# 1                    Pharmacy   0.5
# 2                   Nightclub   0.0
# 3           Mobile Phone Shop   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----La Montagne, Pretoria----
#                   venue  freq
# 0  Fast Food Restaurant  0.23
# 1           Pizza Place  0.15
# 2         Grocery Store  0.15
# 3         Shopping Mall  0.15
# 4           Supermarket  0.08
#
#
# ----Laudium, Pretoria----
#                   venue  freq
# 0         Deli / Bodega  0.17
# 1  Fast Food Restaurant  0.17
# 2           Gas Station  0.17
# 3            Restaurant  0.17
# 4         Grocery Store  0.17
#
#
# ----Les Marais, Pretoria----
#                   venue  freq
# 0  Fast Food Restaurant   0.2
# 1           Gas Station   0.2
# 2            Steakhouse   0.2
# 3          Liquor Store   0.2
# 4         Grocery Store   0.2
#
#
# ----Lotus Gardens, Pretoria----
#                   venue  freq
# 0          Burger Joint  0.16
# 1                 Hotel  0.12
# 2  Fast Food Restaurant  0.12
# 3         Shopping Mall  0.08
# 4        History Museum  0.08
#
#
# ----Lukasrand, Pretoria----
#                   venue  freq
# 0  Ethiopian Restaurant  0.12
# 1                 Trail  0.12
# 2          Burger Joint  0.12
# 3     Food & Drink Shop  0.12
# 4          Concert Hall  0.12
#
#
# ----Lydiana, Pretoria----
#                   venue  freq
# 0              Pharmacy  0.12
# 1  Gym / Fitness Center  0.12
# 2           Pizza Place  0.12
# 3                  Café  0.12
# 4                  Road  0.12
#
#
# ----Lynnwood Glen, Pretoria----
#                 venue  freq
# 0                Café  0.18
# 1         Supermarket  0.09
# 2  Seafood Restaurant  0.09
# 3          Restaurant  0.09
# 4      Rental Service  0.05
#
#
# ----Lynnwood Manor, Pretoria----
#           venue  freq
# 0   Supermarket  0.14
# 1          Café  0.14
# 2    Restaurant  0.09
# 3  Burger Joint  0.09
# 4         Hotel  0.05
#
#
# ----Lynnwood Park, Pretoria----
#               venue  freq
# 0     Shopping Mall  0.17
# 1        Restaurant  0.17
# 2  Sushi Restaurant  0.08
# 3        Food Court  0.08
# 4       Snack Place  0.08
#
#
# ----Lynnwood Ridge, Pretoria----
#                 venue  freq
# 0       Shopping Mall  0.21
# 1         Pizza Place  0.11
# 2  Chinese Restaurant  0.05
# 3        Cocktail Bar  0.05
# 4  Seafood Restaurant  0.05
#
#
# ----Lynnwood, Pretoria----
#                 venue  freq
# 0          Restaurant   0.4
# 1      Cricket Ground   0.2
# 2  Seafood Restaurant   0.2
# 3                 Pub   0.2
# 4                 ATM   0.0
#
#
# ----Mamelodi, Pretoria----
#                         venue  freq
# 0         Fried Chicken Joint   0.5
# 1                        Café   0.5
# 2                   Nightclub   0.0
# 3  Modern European Restaurant   0.0
# 4               Movie Theater   0.0
#
#
# ----Mayville, Pretoria----
#                   venue  freq
# 0          Burger Joint  0.14
# 1  Fast Food Restaurant  0.14
# 2         Shopping Mall  0.14
# 3           Gas Station  0.14
# 4            Restaurant  0.14
#
#
# ----Menlo Park, Pretoria----
#            venue  freq
# 0  Shopping Mall  0.12
# 1    Coffee Shop  0.08
# 2    Pizza Place  0.08
# 3  Grocery Store  0.08
# 4         Bistro  0.08
#
#
# ----Menlyn, Pretoria----
#                    venue  freq
# 0                   Café  0.08
# 1          Shopping Mall  0.06
# 2     Italian Restaurant  0.06
# 3  Portuguese Restaurant  0.04
# 4   Fast Food Restaurant  0.04
#
#
# ----Meyerspark, Pretoria----
#                   venue  freq
# 0  Fast Food Restaurant  0.23
# 1           Pizza Place  0.15
# 2         Grocery Store  0.15
# 3         Shopping Mall  0.15
# 4           Supermarket  0.08
#
#
# ----Montana Park, Pretoria----
#                 venue  freq
# 0       Grocery Store  0.17
# 1          Steakhouse  0.17
# 2           BBQ Joint  0.08
# 3  Chinese Restaurant  0.08
# 4        Burger Joint  0.08
#
#
# ----Monument Park, Pretoria----
#                 venue  freq
# 0       Shopping Mall  0.18
# 1  Seafood Restaurant  0.18
# 2    Department Store  0.09
# 3    Football Stadium  0.09
# 4        Burger Joint  0.09
#
#
# ----Moreleta Park, Pretoria----
#               venue  freq
# 0  Department Store  0.09
# 1               Gym  0.09
# 2       Snack Place  0.09
# 3       Gas Station  0.09
# 4    Clothing Store  0.09
#
#
# ----Mountain View, Pretoria----
#                         venue  freq
# 0                Liquor Store   0.2
# 1                 Gas Station   0.2
# 2           Convenience Store   0.2
# 3  Construction & Landscaping   0.2
# 4                 Snack Place   0.2
#
#
# ----Muckleneuk, Pretoria----
#                   venue  freq
# 0  Ethiopian Restaurant  0.09
# 1                   Bar  0.09
# 2         Shopping Mall  0.09
# 3          Burger Joint  0.09
# 4        Breakfast Spot  0.09
#
#
# ----Murrayfield, Pretoria----
#                   venue  freq
# 0  Fast Food Restaurant  0.23
# 1           Pizza Place  0.15
# 2         Grocery Store  0.15
# 3         Shopping Mall  0.15
# 4           Supermarket  0.08
#
#
# ----New Muckleneuk, Pretoria----
#            venue  freq
# 0     Restaurant  0.08
# 1           Café  0.08
# 2    Pizza Place  0.05
# 3  Deli / Bodega  0.05
# 4    Coffee Shop  0.05
#
#
# ----Newlands, Pretoria----
#                 venue  freq
# 0                Café  0.09
# 1  Seafood Restaurant  0.09
# 2    Department Store  0.05
# 3              Casino  0.05
# 4  Chinese Restaurant  0.05
#
#
# ----Olympus, Pretoria----
#                   venue  freq
# 0                   Zoo  0.25
# 1  Fast Food Restaurant  0.25
# 2     Convenience Store  0.25
# 3    Athletics & Sports  0.25
# 4         Movie Theater  0.00
#
#
# ----Orchards, Pretoria----
#                   venue  freq
# 0          Burger Joint  0.16
# 1                 Hotel  0.12
# 2  Fast Food Restaurant  0.12
# 3         Shopping Mall  0.08
# 4        History Museum  0.08
#
#
# ----Phillip Nel Park, Pretoria----
#                         venue  freq
# 0                 Golf Course  0.67
# 1        Fast Food Restaurant  0.33
# 2                         ATM  0.00
# 3          Miscellaneous Shop  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Pretoria North, Pretoria----
#                   venue  freq
# 0         Grocery Store  0.25
# 1  Fast Food Restaurant  0.12
# 2   Fried Chicken Joint  0.12
# 3           Gas Station  0.12
# 4           Supermarket  0.12
#
#
# ----Pretoria West, Pretoria----
#                   venue  freq
# 0                Bakery  0.50
# 1  Fast Food Restaurant  0.25
# 2            Restaurant  0.25
# 3     Mobile Phone Shop  0.00
# 4         Movie Theater  0.00
#
#
# ----Proclamation Hill, Pretoria----
#                            venue  freq
# 0           Fast Food Restaurant  0.50
# 1                        Gay Bar  0.25
# 2                   Soccer Field  0.25
# 3                           Park  0.00
# 4  Paper / Office Supplies Store  0.00
#
#
# ----Rietvalleirand, Pretoria----
#                 venue  freq
# 0        Burger Joint  0.14
# 1                 Gym  0.14
# 2  Seafood Restaurant  0.14
# 3  Chinese Restaurant  0.14
# 4       Shopping Mall  0.14
#
#
# ----Rosslyn, Pretoria----
#                         venue  freq
# 0          Light Rail Station  0.50
# 1                    Platform  0.25
# 2                        Road  0.25
# 3           Mobile Phone Shop  0.00
# 4  Modern European Restaurant  0.00
#
#
# ----Salvokop, Pretoria----
#                   venue  freq
# 0  Fast Food Restaurant  0.25
# 1                 Hotel  0.17
# 2         Train Station  0.17
# 3        History Museum  0.17
# 4         Auto Workshop  0.08
#
#
# ----Silverton, Pretoria----
#                    venue  freq
# 0            Pizza Place   0.2
# 1  Portuguese Restaurant   0.2
# 2      Convenience Store   0.2
# 3            Gas Station   0.2
# 4   Fast Food Restaurant   0.2
#
#
# ----Sinoville, Pretoria----
#                         venue  freq
# 0            Department Store  0.25
# 1                  Restaurant  0.25
# 2               Shopping Mall  0.25
# 3                 Gas Station  0.25
# 4  Modern European Restaurant  0.00
#
#
# ----Sterrewag, Pretoria----
#               venue  freq
# 0      Burger Joint  0.14
# 1        Restaurant  0.14
# 2             Hotel  0.14
# 3     Shopping Mall  0.14
# 4  Football Stadium  0.14
#
#
# ----Sunnyside, Pretoria----
#             venue  freq
# 0     Gas Station  0.12
# 1          Market  0.12
# 2   Shopping Mall  0.12
# 3    Burger Joint  0.12
# 4  Breakfast Spot  0.12
#
#
# ----The Orchards, Pretoria----
#                   venue  freq
# 0          Burger Joint  0.16
# 1                 Hotel  0.12
# 2  Fast Food Restaurant  0.12
# 3         Shopping Mall  0.08
# 4        History Museum  0.08
#
#
# ----Theresapark, Pretoria----
#                 venue  freq
# 0         Gas Station   0.4
# 1      Breakfast Spot   0.2
# 2   Convenience Store   0.2
# 3  Seafood Restaurant   0.2
# 4                 ATM   0.0
#
#
# ----Trevenna, Pretoria----
#                    venue  freq
# 0                  Hotel  0.20
# 1   Fast Food Restaurant  0.13
# 2          Shopping Mall  0.13
# 3  Portuguese Restaurant  0.07
# 4                   Café  0.07
#
#
# ----Val de Grace, Pretoria----
#                   venue  freq
# 0              Pharmacy  0.12
# 1  Gym / Fitness Center  0.12
# 2           Pizza Place  0.12
# 3        Clothing Store  0.12
# 4                  Road  0.12
#
#
# ----Wapadrand, Pretoria----
#                 venue  freq
# 0           Nightclub  0.11
# 1  Chinese Restaurant  0.11
# 2          Steakhouse  0.06
# 3       Shopping Mall  0.06
# 4              Casino  0.06
#
#
# ----Waterkloof Glen, Pretoria----
#               venue  freq
# 0        Restaurant  0.22
# 1          Pharmacy  0.11
# 2  Department Store  0.11
# 3              Café  0.11
# 4               Pub  0.11
#
#
# ----Waterkloof Park, Pretoria----
#            venue  freq
# 0           Café  0.13
# 1  Deli / Bodega  0.10
# 2    Pizza Place  0.10
# 3     Restaurant  0.06
# 4    Coffee Shop  0.06
#
#
# ----Waterkloof Ridge, Pretoria----
#                venue  freq
# 0     Clothing Store   0.4
# 1         Playground   0.2
# 2               Park   0.2
# 3              Hotel   0.2
# 4  Indian Restaurant   0.0
#
#
# ----Waterkloof, Pretoria----
#            venue  freq
# 0           Café  0.13
# 1  Deli / Bodega  0.10
# 2    Pizza Place  0.10
# 3     Restaurant  0.06
# 4    Coffee Shop  0.06
#
#
# ----Waverley, Pretoria----
#                      venue  freq
# 0                      Spa  0.33
# 1                   Market  0.33
# 2                      Gym  0.33
# 3  New American Restaurant  0.00
# 4       Miscellaneous Shop  0.00
#
#
# ----Weskoppies, Pretoria----
#                         venue  freq
# 0                Burger Joint   0.5
# 1                       Trail   0.5
# 2                   Nightclub   0.0
# 3           Mobile Phone Shop   0.0
# 4  Modern European Restaurant   0.0
#
#
# ----Wespark, Pretoria----
#                   venue  freq
# 0         Deli / Bodega  0.25
# 1          Liquor Store  0.25
# 2           Gas Station  0.25
# 3  Fast Food Restaurant  0.25
# 4                  Park  0.00
#
#
# ----Willow Glen, Pretoria----
#               venue  freq
# 0        Restaurant  0.22
# 1          Pharmacy  0.11
# 2  Department Store  0.11
# 3              Café  0.11
# 4               Pub  0.11
#
#
# ----Wingate Park, Pretoria----
#                 venue  freq
# 0       Shopping Mall  0.17
# 1         Golf Course  0.17
# 2         Pizza Place  0.17
# 3        Burger Joint  0.08
# 4  Italian Restaurant  0.08
#
#
# ----Wolmer, Pretoria----
#                 venue  freq
# 0  Light Rail Station  0.33
# 1            Platform  0.17
# 2       Shopping Mall  0.17
# 3   Convenience Store  0.17
# 4      Clothing Store  0.17
#
#
# ----Wonderboom South, Pretoria----
#                  venue  freq
# 0                Diner   0.2
# 1          Gas Station   0.2
# 2    Convenience Store   0.2
# 3  Rental Car Location   0.2
# 4   Chinese Restaurant   0.2
#
#
# ----Woodhill, Pretoria----
#             venue  freq
# 0            Café  0.08
# 1           Diner  0.05
# 2   Grocery Store  0.05
# 3  Breakfast Spot  0.05
# 4  Clothing Store  0.05
#
#
# ----Woodlands, Pretoria----
#                   venue  freq
# 0          Burger Joint  0.16
# 1                 Hotel  0.12
# 2  Fast Food Restaurant  0.12
# 3         Shopping Mall  0.08
# 4        History Museum  0.08

# %%
# write a function that puts the most common places in a dataframe 

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
# Create a dataframe that consists of the 10 most common places in a neighbourhood

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighbourhoods_venues_sorted = pd.DataFrame(columns=columns)
neighbourhoods_venues_sorted['Neighbourhood'] = pta_grouped['Neighbourhood']

for ind in np.arange(pta_grouped.shape[0]):
    neighbourhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(pta_grouped.iloc[ind, :], num_top_venues)

neighbourhoods_venues_sorted.head()
# Out:
#               Neighbourhood  ... 10th Most Common Venue
# 0     Alphen Park, Pretoria  ...          Grocery Store
# 1       Amandasig, Pretoria  ...      French Restaurant
# 2         Arcadia, Pretoria  ...  Portuguese Restaurant
# 3  Ashlea Gardens, Pretoria  ...     Falafel Restaurant
# 4  Atteridgeville, Pretoria  ...                    Zoo
#
# [5 rows x 11 columns]

# %%
neighbourhoods_venues_sorted.shape
# Out:
# (88, 11)

# %%
# set number of clusters
kclusters = 5

pta_clustering = pta_grouped.drop('Neighbourhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(pta_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 4, 2, 0, 1, 0, 2, 2, 0, 2], dtype=int32)

# %%
len(kmeans.labels_)
# Out:
# 88

# %%
suburbs['Neighbourhood'] = suburbs['Suburb']

# %%
# add clustering labels
neighbourhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

pta_merged = suburbs

# merge manhattan_grouped with manhattan_data to add latitude/longitude for each neighborhood
pta_merged = pta_merged.join(neighbourhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

# %%
pta_merged.dropna(inplace=True)

# %%
pta_merged['Cluster Labels'] = pta_merged['Cluster Labels'].astype(int)

# %% [markdown]
# Map the clusters

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(pta_merged['latitude'], pta_merged['longitude'], pta_merged['Neighbourhood'], pta_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)

# %%
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%3Dfalse%3B%20L_NO_TOUCH%3Dfalse%3B%20L_DISABLE_3D%3Dfalse%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.4.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%3Cstyle%3E%23map_97206ed052e247869c6889ee31bf24f2%20%7B%0A%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%3C/style%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_97206ed052e247869c6889ee31bf24f2%22%20%3E%3C/div%3E%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%0A%0A%20%20%20%20var%20map_97206ed052e247869c6889ee31bf24f2%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%27map_97206ed052e247869c6889ee31bf24f2%27%2C%20%7B%0A%20%20%20%20%20%20%20%20center%3A%20%5B-25.7459374%2C%2028.1879444%5D%2C%0A%20%20%20%20%20%20%20%20zoom%3A%2011%2C%0A%20%20%20%20%20%20%20%20maxBounds%3A%20bounds%2C%0A%20%20%20%20%20%20%20%20layers%3A%20%5B%5D%2C%0A%20%20%20%20%20%20%20%20worldCopyJump%3A%20false%2C%0A%20%20%20%20%20%20%20%20crs%3A%20L.CRS.EPSG3857%2C%0A%20%20%20%20%20%20%20%20zoomControl%3A%20true%2C%0A%20%20%20%20%20%20%20%20%7D%29%3B%0A%0A%0A%20%20%20%20%0A%20%20%20%20var%20tile_layer_bbd8da66fb024770935ff2046e6a67cb%20%3D%20L.tileLayer%28%0A%20%20%20%20%20%20%20%20%27https%3A//%7Bs%7D.tile.openstreetmap.org/%7Bz%7D/%7Bx%7D/%7By%7D.png%27%2C%0A%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%22attribution%22%3A%20null%2C%0A%20%20%20%20% ...

# %%
pta_merged['Cluster Labels'].value_counts()

# %% [markdown]
# Analyse the clusters

# %%
pta_merged.loc[pta_merged['Cluster Labels'] == 0, pta_merged.columns[[1] + list(range(5, pta_merged.shape[1]))]]
# Out:
#       latitude  ... 10th Most Common Venue
# 2   -25.785833  ...     Falafel Restaurant
# 5   -25.740501  ...       Department Store
# 27  -25.761111  ...                Exhibit
# 36  -25.780621  ...       Department Store
# 37  -25.762500  ...                   Park
# 46  -25.757500  ...            Fabric Shop
# 62  -25.727339  ...            Fabric Shop
# 63  -25.675556  ...                    Zoo
# 65  -25.700000  ...         Farmers Market
# 67  -25.709722  ...         Farmers Market
# 68  -25.712500  ...         Farmers Market
# 76  -25.672735  ...            Flower Shop
# 81  -25.673056  ...     Falafel Restaurant
# 90  -25.716389  ...     Falafel Restaurant
# 92  -25.787778  ...     Falafel Restaurant
# 93  -25.708611  ...         Farmers Market
# 94  -25.701111  ...      Food & Drink Shop
# 95  -25.699722  ...            Flower Shop
# 101 -25.757806  ...     Falafel Restaurant
#
# [19 rows x 11 columns]

# %%
pta_merged.loc[pta_merged['Cluster Labels'] == 1, pta_merged.columns[[1] + list(range(5, pta_merged.shape[1]))]]
# Out:
#      latitude  ... 10th Most Common Venue
# 77 -25.650770  ...            Fabric Shop
# 82 -25.663056  ...                Exhibit
# 83 -25.762982  ...                    Zoo
#
# [3 rows x 11 columns]

# %%
pta_merged.loc[pta_merged['Cluster Labels'] == 2, pta_merged.columns[[1] + list(range(5, pta_merged.shape[1]))]]
# Out:
#       latitude  ... 10th Most Common Venue
# 0   -25.782890  ...          Grocery Store
# 1   -25.745627  ...  Portuguese Restaurant
# 3   -25.765556  ...       Greek Restaurant
# 4   -25.744224  ...     Falafel Restaurant
# 7   -25.739981  ...  Portuguese Restaurant
# ..         ...  ...                    ...
# 91  -25.757778  ...      Electronics Store
# 96  -25.749472  ...     Falafel Restaurant
# 97  -25.753611  ...     Falafel Restaurant
# 98  -25.761111  ...             Food Court
# 100 -25.765403  ...                    Zoo
#
# [63 rows x 11 columns]

# %%
pta_merged.loc[pta_merged['Cluster Labels'] == 3, pta_merged.columns[[1] + list(range(5, pta_merged.shape[1]))]]
# Out:
#      latitude  ... 10th Most Common Venue
# 87 -25.708611  ...                Exhibit
#
# [1 rows x 11 columns]

# %%
pta_merged.loc[pta_merged['Cluster Labels'] == 4, pta_merged.columns[[1] + list(range(5, pta_merged.shape[1]))]]
# Out:
#      latitude  ... 10th Most Common Venue
# 66 -25.675000  ...      French Restaurant
# 69 -25.663333  ...     Falafel Restaurant
#
# [2 rows x 11 columns]
